# %%
import pandas as pd

df = pd.read_csv("final_fixed.csv")
df.tail(
    
)
# Out:
#                        Name  \
# 376         Ooh La La Lemon
# 377           Classic Cosmo
# 378        Strawberry Basil
# 379  Skinnygirl Bloody Mary
# 380         Handsome Ginger
#
#                                                   Link  \
# 376  https://www.thecocktailproject.com/drink-recip...
# 377  https://www.thecocktailproject.com/drink-recip...
# 378  https://www.thecocktailproject.com/drink-recip...
# 379  https://www.thecocktailproject.com/drink-recip...
# 380  https://www.thecocktailproject.com/drink-recip...
#
#                                            Ingredients Main Spirit  Flavor  \
# 376  Pinnacle Whipped Vodka, Lemonade, Pinnacle Whi...       Vodka   Sweet
# 377  EFFEN Vodka, Cranberry Juice, EFFEN Vodka, Cra...       Vodka   Sweet
# 378  Strawberries, Strawberries, Basil, Soda Water,...       Vodka  Fruity
# 379  Skinnygirl Cucumber Vodka, Hot Sauce, Skinnygi...       Vodka  Savory
# 380  Pinnacle Original Vodka, Ginger Beer, Pinnacle...       Vodka   Sweet
#
# ...

# %%
df['Occasion']
# Out:
# 0           ['birthday', 'fall', 'new-years', 'winter']
# 1       ['birthday', 'holiday', 'new-years', 'wedding']
# 2                                  ['spring', 'summer']
# 3                 ['bbq', 'brunch', 'spring', 'summer']
# 4                 ['bbq', 'brunch', 'spring', 'summer']
#                              ...
# 376    ['birthday', 'ladies-night', 'spring', 'summer']
# 377                          ['ladies-night', 'summer']
# 378                                   ['bbq', 'summer']
# 379                                          ['brunch']
# 380                                          ['summer']
# Name: Occasion, Length: 381, dtype: object
