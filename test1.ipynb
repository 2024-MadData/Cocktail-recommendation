# %%
import pandas as pd

df = pd.read_csv("final_fixed.csv")
df.head()
# Out:
#                Name                                               Link  \
# 0  Espresso Martini  https://www.thecocktailproject.com/Espresso-Ma...
# 1         French 75       https://www.thecocktailproject.com/French-75
# 2         Last Word       https://www.thecocktailproject.com/Last-Word
# 3       Tom Collins     https://www.thecocktailproject.com/Tom-Collins
# 4     Tokyo Collins   https://www.thecocktailproject.com/Tokyo-Collins
#
#                                          Ingredients Main Spirit      Flavor  \
# 0  EFFEN Original Vodka, Coffee Liqueur, EFFEN Or...       Vodka       Sweet
# 1  Sipsmith London Dry Gin, Lemon Juice, Sipsmith...         Gin  Refreshing
# 2  Sipsmith London Dry Gin, Lime Juice, Sipsmith ...         Gin        Sour
# 3  Sipsmith London Dry Gin, Lemon Juice, Sipsmith...         Gin  Refreshing
# 4  Suntory Roku Gin, Lemon Juice, Suntory Roku Gi...         Gin  Refreshing
#
#    Rating  Ratings Count       Color  \
# ...
